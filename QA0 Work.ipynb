# %%
import numpy as np
import pandas as pd
import asdmCal as cal
c = cal.open_conn()
import matplotlib.pyplot as plt
# %matplotlib inline
import DataBase as db
datas = db.Database(verbose=False, forcenew=False, path='/.qa0')
datas.process_sbs()
datas.do_summarize_sb()
import sys
import os
import shutil
# Out:
# 42
# /data1/home/aod/anaconda/lib/python2.7/site-packages/pandas/computation/align.py:98: RuntimeWarning: divide by zero encountered in log10
#   ordm = np.log10(abs(reindexer_size - term_axis_size))

# %%
caldata = cal.query_last_day(c).sort('TIME', ascending=False)
eb = caldata.groupby('UID').agg({'SCAN': np.max, 'TIME': np.min}).sort('TIME', ascending=False)
eb.columns = pd.Index(['START_TIME', u'NUM_SCAN'], dtype='object')
eb.index.name = 'EB_UID'
slt=cal.query_stl(c, '2015-05-15 00:00:00')
slt_eb = pd.merge(eb, slt[['SE_ID', 'SE_SUBJECT', 'SE_PROJECT_CODE', 'SE_SB_ID', 'SE_EB_UID', 'SE_STATUS', 
                           'SE_ARRAYENTRY_ID', 'SE_SB_CODE']], 
                  left_index=True, right_on='SE_EB_UID')
slt_eb = pd.merge(slt_eb, slt[['SE_ID', 'SE_ARRAYNAME', 'SE_ARRAYTYPE', 'SE_ARRAYFAMILY', 'SE_CORRELATORTYPE']],
                  left_on='SE_ARRAYENTRY_ID', right_on='SE_ID')
slt_eb = slt_eb.set_index('SE_EB_UID', drop=False)[['SE_EB_UID', 'START_TIME', 'NUM_SCAN', 'SE_STATUS',
                                                    'SE_SB_ID', 'SE_SB_CODE', 'SE_PROJECT_CODE', 'SE_ARRAYNAME',
                                                    'SE_ARRAYFAMILY', 'SE_CORRELATORTYPE', 'SE_ID_y', 'SE_SUBJECT']
                                                  ].sort('START_TIME', ascending=False)
csv = slt_eb[slt_eb.SE_PROJECT_CODE.str.endswith(".CSV")].SE_PROJECT_CODE.unique()
uids = slt_eb.query('SE_PROJECT_CODE not in @csv and SE_ARRAYFAMILY == "12 [m]"').SE_EB_UID.unique()
slt_eb.query('SE_PROJECT_CODE not in @csv').head(50)[
    ['SE_EB_UID', 'NUM_SCAN', 'SE_STATUS', 'SE_SB_CODE', 'SE_ARRAYFAMILY']]
# Out:
# 4939103027000000512
# SELECT ARCHIVE_UID, CAL_DATA_ID, START_TIME_OBSERVED, CAL_TYPE_ENUMV, SCAN_SET_VAL FROM SCHEDULING_AOS.ASDM_CALDATA WHERE START_TIME_OBSERVED > 4939103027000000512
# Executing QUERY, please wait...
# SELECT SE_ID, SE_SUBJECT, SE_TIMESTAMP, SE_START, SE_ARRAYENTRY_ID,SE_ARRAYNAME, SE_ARRAYTYPE, SE_ARRAYFAMILY, SE_CORRELATORTYPE, SE_PROJECT_CODE, SE_SB_ID, SE_EB_UID, SE_STATUS, SE_TYPE, SE_SB_CODE FROM ALMA.SHIFTLOG_ENTRIES WHERE SE_TIMESTAMP >  to_date('2015-05-15 00:00:00', 'YYYY-MM-DD HH24:MI:SS') AND SE_LOCATION = 'OSF-AOS'
# Executing QUERY for SLT, please wait...
#                                          SE_EB_UID  NUM_SCAN SE_STATUS             SE_SB_CODE SE_ARRAYFAMILY
# SE_EB_UID
# uid://A002/Xa1a7ec/X5d4    uid://A002/Xa1a7ec/X5d4        20   SUCCESS         VV_219_a_03_TE         12 [m]
# uid://A002/Xa1a7ec/X3b2    uid://A002/Xa1a7ec/X3b2         7   SUCCESS          3c279_a_03_TP    Total Power
# uid://A002/Xa1a7ec/X23a    uid://A002/Xa1a7ec/X23a        26   SUCCESS           2379_a_03_TE         12 [m]
# uid://A002/Xa1a7ec/Xc4      uid://A002/Xa1a7ec/Xc4        15   SUCCESS       cloud_22_b_03_TP    Total Power
# uid://A002/Xa18feb/X2774  uid://A002/Xa18feb/X2774        12   SUCCESS       RGB_J015_a_04_TE         12 [m]
# uid://A002/Xa18feb/X2551  uid://A002/Xa18feb/X2551        18   SUCCESS  vv114_a_04_TE_tuning2         12 [m]
# uid://A002/Xa18feb/X22b0  uid://A002/Xa18feb/X22b0        18   SUCCESS  vv114_a_04_TE_tuning1         12 [m]
# uid://A002/Xa18feb/X1f9f  uid://A002/Xa18feb/X1f9f        11   SUCCESS       2355-534_a_03_TE         12 [m]
# uid://A002/Xa18feb/X1e36  uid://A002/Xa18feb/X1e36        12   SUCCESS       Circumnu_b_06_TP    Total Power
# uid://A002/Xa18feb/X1def  uid://A002/Xa18feb/X1def        11   SUCCESS       2326-477_a_03_TE         12 [m]
# uid://A002/Xa18feb/X18a4  uid://A002/Xa18feb/X18a4        66   SUCCESS       16263_24_a_06_TE         12 [m]
# uid://A002/Xa18feb/X176d  uid://A002/Xa18feb/X176d        11   SUCCESS       1933-400_b_03_TE         12 [m]
# uid://A002/Xa18feb/X161b  uid://A002/Xa18feb/X161b        16   SUCCESS       1730-130_b_03_TE         12 [m]
# uid://A002/Xa18feb/X140a  uid://A002/Xa18feb/X140a        12   SUCCESS       Circumnu_b_06_TP    Total Power
# uid://A002/Xa18feb/X135b  uid://A002/Xa18feb/X135b        26   SUCCESS           2408_a_03_TE         12 [m]
# uid://A002/Xa18feb/X120d  uid://A002/Xa18feb/X120d        12   SUCCESS       Circumnu_b_06_TP    Total Power
# uid://A002/Xa18feb/Xefd    uid://A002/Xa18feb/Xefd        26   SUCCESS           5249_a_03_TE         12 [m]
# uid://A002/Xa18feb/Xd73    uid://A002/Xa18feb/Xd73        12   SUCCESS       Circumnu_b_06_TP    Total Power
# uid://A002/Xa18feb/Xc9a    uid://A002/Xa18feb/Xc9a        24   SUCCESS           5082_a_03_TE         12 [m]
# uid://A002/Xa18feb/Xab3    uid://A002/Xa18feb/Xab3        10   SUCCESS       G0.25+0._b_06_TP    Total Power
# uid://A002/Xa18feb/X959    uid://A002/Xa18feb/X959        27   SUCCESS           5511_a_03_TE         12 [m]
# uid://A002/Xa18feb/X7f3    uid://A002/Xa18feb/X7f3        10   SUCCESS       G0.25+0._b_06_TP    Total Power
# uid://A002/Xa18feb/X71d    uid://A002/Xa18feb/X71d        48   SUCCESS           7248_a_03_TE         12 [m]
# uid://A002/Xa18feb/X32f    uid://A002/Xa18feb/X32f        24   SUCCESS       Cha-MMS1_a_03_TE         12 [m]
# uid://A002/Xa16f89/X4eb9  uid://A002/Xa16f89/X4eb9        12   SUCCESS       J0454-81_a_03_TE         12 [m]
# uid://A002/Xa16f89/X4c9f  uid://A002/Xa16f89/X4c9f        12   SUCCESS       NGC_1614_a_06_TE         12 [m]
# uid://A002/Xa16f89/X4c65  uid://A002/Xa16f89/X4c65        18   SUCCESS       HOPS_287_a_06_TP    Total Power
# uid://A002/Xa16f89/X4b05  uid://A002/Xa16f89/X4b05        12   SUCCESS       1ES_0414_a_04_TE         12 [m]
# uid://A002/Xa16f89/X44e3  uid://A002/Xa16f89/X44e3        20   SUCCESS         DQ_Tau_a_06_12         12 [m]
# uid://A002/Xa16f89/X4167  uid://A002/Xa16f89/X4167        18   SUCCESS       HOPS_287_a_06_TP    Total Power
# uid://A002/Xa16f89/X3d63  uid://A002/Xa16f89/X3d63        18   SUCCESS       HOPS_287_a_06_TP    Total Power
# uid://A002/Xa16f89/X3d53  uid://A002/Xa16f89/X3d53        72   SUCCESS       L1527_IR_a_06_TC         12 [m]
# uid://A002/Xa16f89/X39b4  uid://A002/Xa16f89/X39b4        18   SUCCESS       HOPS_287_a_06_TP    Total Power
# uid://A002/Xa16f89/X3890  uid://A002/Xa16f89/X3890        26   SUCCESS           A383_a_06_TE         12 [m]
# uid://A002/Xa16f89/X36b8  uid://A002/Xa16f89/X36b8         8   SUCCESS         Uranus_a_06_TP    Total Power
# uid://A002/Xa16f89/X333c  uid://A002/Xa16f89/X333c         8   SUCCESS         Uranus_a_06_TP    Total Power
# uid://A002/Xa16f89/X3287  uid://A002/Xa16f89/X3287        25   SUCCESS           A383_a_06_TE         12 [m]
# uid://A002/Xa16f89/X2d8a  uid://A002/Xa16f89/X2d8a         7   SUCCESS         Uranus_b_06_TP    Total Power
# uid://A002/Xa16f89/X2a8c  uid://A002/Xa16f89/X2a8c        24   SUCCESS        NGC1365_a_06_TE         12 [m]
# uid://A002/Xa16f89/X29e3  uid://A002/Xa16f89/X29e3         8   SUCCESS         Uranus_b_06_TP    Total Power
# uid://A002/Xa16f89/X26dc  uid://A002/Xa16f89/X26dc        18   SUCCESS  vv114_a_04_TE_tuning3         12 [m]
# uid://A002/Xa16f89/X265d  uid://A002/Xa16f89/X265d         7   SUCCESS         Uranus_a_06_TP    Total Power
# uid://A002/Xa16f89/X2404  uid://A002/Xa16f89/X2404        18   SUCCESS  vv114_a_04_TE_tuning4         12 [m]
# uid://A002/Xa16f89/X2322  uid://A002/Xa16f89/X2322        12   SUCCESS       Circumnu_b_06_TP    Total Power
# uid://A002/Xa16f89/X2114  uid://A002/Xa16f89/X2114        11   SUCCESS       2331+073_a_03_TE         12 [m]
# uid://A002/Xa16f89/X2092  uid://A002/Xa16f89/X2092        12   SUCCESS       Circumnu_b_06_TP    Total Power
# uid://A002/Xa16f89/X1fa9  uid://A002/Xa16f89/X1fa9        10   SUCCESS        NGC7469_a_03_TE         12 [m]
# uid://A002/Xa16f89/X1e17  uid://A002/Xa16f89/X1e17        10   SUCCESS       J2230+11_a_03_TE         12 [m]
# uid://A002/Xa16f89/X1cc3  uid://A002/Xa16f89/X1cc3        12   SUCCESS       Circumnu_b_06_TP    Total Power
# uid://A002/Xa16f89/X1b6c  uid://A002/Xa16f89/X1b6c        18   SUCCESS       G9.62+0._a_06_TE         12 [m]

# %%
for uid in uids:
    print slt_eb.query('SE_EB_UID == @uid')
    timeu = slt_eb.ix[uid, 'START_TIME']
    tmjd = timeu.strftime('%Y-%m-%dT%H:%M:%S.%s')
    point_eb = cal.query_point(c, uid, q1=True)
    dfph = cal.query_phase(c, uid)
    dfatm = cal.query_atm(c, uid)
    dfant = cal.query_antennas(c, uid)
    dfflag = cal.query_flags(c, uid)
    dfflag.delta = dfflag.apply(lambda x: x['delta'].total_seconds(), axis=1)
    dfscan = cal.query_scans(c, uid)
    dfsta = cal.query_station(c, uid)
    dfsubs = cal.query_subscans(c, uid)
    dffoc = cal.query_focus(c, tmjd)
    dfdel = cal.query_delay(c, tmjd)
    dfield = cal.query_field(c, uid)
    dfmain = cal.query_main(c, uid)
    dfwvr = cal.query_wvr(c, uid)
    dfcal = cal.query_caldata(c, uid)
    ssys = ['Mars', 'Venus', 'Jupiter', 'Uranus', 'Neptune', 'Titan', 'Ceres', 'Ganymede', 'Callisto', 'Pallas']
    calamp = dfscan.query("SCAN_INTENT in ['CALIBRATE_AMPLITUDE', 'CALIBRATE_AMPLI'] and FIELD_NAME not in @ssys").FIELD_NAME.unique()

    if len(calamp) > 0:
        cou = 0
        for ca in calamp:
            sql_names = 'SELECT * FROM sourcecatalogue.names WHERE SOURCE_NAME = \'%s\'' % ca
            c.execute(sql_names)
            names = pd.DataFrame(
                c.fetchall(),
                columns=[rec[0] for rec in c.description])

            name_id = names.NAME_ID.values[0]

            sql_sourcename = 'SELECT * FROM sourcecatalogue.source_name WHERE NAME_ID = \'%s\'' % name_id
            c.execute(sql_sourcename)
            source_name = pd.DataFrame(
                c.fetchall(), columns=[rec[0] for rec in c.description])
            source_id = source_name.SOURCE_ID.values[0]
            c.execute('SELECT * FROM SOURCECATALOGUE.MEASUREMENTS WHERE SOURCE_ID = \'%s\'' % source_id)
            measurements_df = pd.DataFrame(
                c.fetchall(),
                columns=[rec[0] for rec in c.description])
            if cou == 0:
                cal_amp = measurements_df.query('FREQUENCY < 1.40e11').sort('DATE_OBSERVED', ascending=False).head(1)
                cal_amp = cal_amp.append(measurements_df.query('FREQUENCY > 2.00e11').sort('DATE_OBSERVED', ascending=False).head(1))
                cou = 1
            else:
                cal_amp = cal_amp.append(measurements_df.query('FREQUENCY > 2.00e11').sort('DATE_OBSERVED', ascending=False).head(1))
                cal_amp = cal_amp.append(measurements_df.query('FREQUENCY < 1.40e11').sort('DATE_OBSERVED', ascending=False).head(1))
    else:
        cal_amp = pd.DataFrame([(0,0)], columns=['MEASUREMENT_ID', 'CAT_ID'])
    dire = '_'.join(uid.split('/')[-2:])
    try:
        os.mkdir('data/' + dire)
    except OSError:
        shutil.rmtree('data/' + dire)
        os.mkdir('data/' + dire)
        
    point_eb[0].to_csv('data/' + dire + '/point_qa0.csv', index=False)
    antenas = dfant.ANTENNA.unique()
    point_eb[1].query('ANTENNA in @antenas').to_csv('data/' + dire + '/point_qa1.csv', index=False)
    dfant.to_csv('data/' + dire + '/antennas.csv', index=False)
    dfph.to_csv('data/' + dire + '/phase.csv', index=False)
    dfwvr.to_csv('data/' + dire + '/wvr.csv', index=False)
    dfscan.to_csv('data/' + dire + '/scan.csv', index=False)
    dfatm.to_csv('data/' + dire + '/atmosphere.csv', index=False)
    dfdel.query('ANTENNA in @antenas').to_csv('data/' + dire + '/delay.csv', index=False)
    dfmain.to_csv('data/' + dire + '/main.csv', index=False)
    dfield.to_csv('data/' + dire + '/field.csv', index=False)
    dffoc.query('ANTENNA in @antenas').to_csv('data/' + dire + '/focus.csv', index=False)
    dfsubs.to_csv('data/' + dire + '/subscans.csv', index=False)
    dfflag.to_csv('data/' + dire + '/flags.csv', index=False)
    dfcal.to_csv('data/' + dire + '/caldata.csv', index=False)
    slt_eb.query('SE_EB_UID == @uid').to_csv('data/' + dire + '/slt.csv', index=False)
    sbuid = slt_eb.query('SE_EB_UID == @uid').SE_SB_ID.values[0]
    datas.summary_sb.query("SB_UID == @sbuid").to_csv('data/' + dire + '/sbsum.csv', index=False)
    scpar = datas.scienceparam.query('SB_UID == @sbuid').paramRef.unique()
    tar = datas.target.query('SB_UID == @sbuid and paramRef in @scpar').fieldRef.unique()
    datas.fieldsource.query('SB_UID == @sbuid and @tar in fieldRef').to_csv('data/' + dire + '/fieldsource.csv', index=False)
    datas.scienceparam.query('SB_UID == @sbuid').to_csv('data/' + dire + '/scienceparam.csv', index=False)
    cal_amp.to_csv('data/' + dire + '/cal_amp.csv', index=False)
# Out:
#                                        SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS             SE_SB_ID      SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY SE_CORRELATORTYPE  \
# SE_EB_UID
# uid://A002/Xa1a7ec/X5d4  uid://A002/Xa1a7ec/X5d4 2015-05-25 22:02:50.575000        20   SUCCESS  uid://A001/X144/X7d  VV_219_a_03_TE  2013.1.01332.S     Array006         12 [m]                BL
#
#                          SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa1a7ec/X5d4   783461  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939284100800000000 AND START_VALID_TIME < 4939309300800000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939286570143258624.000000 AND START_VALID_TIME <4939308170143258624.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939286570143258624.000000 AND START_VALID_TIME <4939308170143258624.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X5d4'
# Executing QUERY, please wait...
#                                        SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID    SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY SE_CORRELATORTYPE  \
# SE_EB_UID
# uid://A002/Xa1a7ec/X23a  uid://A002/Xa1a7ec/X23a 2015-05-25 21:08:49.519000        26   SUCCESS  uid://A001/X144/X1bd  2379_a_03_TE  2013.1.00115.S     Array006         12 [m]                BL
#
#                          SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa1a7ec/X23a   783461  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939279785264000000 AND START_VALID_TIME < 4939304985264000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939283329143259136.000000 AND START_VALID_TIME <4939304929143259136.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939283329143259136.000000 AND START_VALID_TIME <4939304929143259136.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa1a7ec/X23a'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS             SE_SB_ID        SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X2774  uid://A002/Xa18feb/X2774 2015-05-25 11:13:24.649000        12   SUCCESS  uid://A001/X120/X39  RGB_J015_a_04_TE  2013.1.00989.S     Array012         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X2774                BL   783214  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939244704848000000 AND START_VALID_TIME < 4939269904848000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939247604143255552.000000 AND START_VALID_TIME <4939269204143255552.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939247604143255552.000000 AND START_VALID_TIME <4939269204143255552.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2774'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID             SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X2551  uid://A002/Xa18feb/X2551 2015-05-25 10:28:07.470999        18   SUCCESS  uid://A001/X12b/X209  vv114_a_04_TE_tuning2  2013.1.01057.S     Array012         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X2551                BL   783214  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939242190800000000 AND START_VALID_TIME < 4939267390800000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939244887143255040.000000 AND START_VALID_TIME <4939266487143255040.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939244887143255040.000000 AND START_VALID_TIME <4939266487143255040.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X2551'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID             SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X22b0  uid://A002/Xa18feb/X22b0 2015-05-25 09:43:13.424001        18   SUCCESS  uid://A001/X12b/X208  vv114_a_04_TE_tuning1  2013.1.01057.S     Array012         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X22b0                BL   783214  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939239470976000000 AND START_VALID_TIME < 4939264670976000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939242193143255040.000000 AND START_VALID_TIME <4939263793143255040.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939242193143255040.000000 AND START_VALID_TIME <4939263793143255040.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X22b0'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID        SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X1f9f  uid://A002/Xa18feb/X1f9f 2015-05-25 08:57:47.041000        11   SUCCESS  uid://A001/X122/X16d  2355-534_a_03_TE  2013.1.00700.S     Array008         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X1f9f                BL   783130  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939236842928000000 AND START_VALID_TIME < 4939262042928000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939239467143254016.000000 AND START_VALID_TIME <4939261067143254016.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939239467143254016.000000 AND START_VALID_TIME <4939261067143254016.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1f9f'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID        SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X1def  uid://A002/Xa18feb/X1def 2015-05-25 08:28:08.298000        11   SUCCESS  uid://A001/X122/X16c  2326-477_a_03_TE  2013.1.00700.S     Array008         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X1def                BL   783130  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939235047152000000 AND START_VALID_TIME < 4939260247152000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939237688143254528.000000 AND START_VALID_TIME <4939259288143254528.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939237688143254528.000000 AND START_VALID_TIME <4939259288143254528.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X1def'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID        SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X18a4  uid://A002/Xa18feb/X18a4 2015-05-25 06:56:38.619000        66   SUCCESS  uid://A001/X144/X181  16263_24_a_06_TE  2013.1.00937.S     Array008         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X18a4                BL   783130  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939228674528000000 AND START_VALID_TIME < 4939253874528000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939232198143253504.000000 AND START_VALID_TIME <4939253798143253504.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939232198143253504.000000 AND START_VALID_TIME <4939253798143253504.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X18a4'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID        SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X176d  uid://A002/Xa18feb/X176d 2015-05-25 06:23:46.948000        11   SUCCESS  uid://A001/X147/X173  1933-400_b_03_TE  2013.1.00428.S     Array008         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X176d                BL   783130  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939226702976000000 AND START_VALID_TIME < 4939251902976000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939230226143253504.000000 AND START_VALID_TIME <4939251826143253504.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939230226143253504.000000 AND START_VALID_TIME <4939251826143253504.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X176d'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID        SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa18feb/X161b  uid://A002/Xa18feb/X161b 2015-05-25 05:52:17.759000        16   SUCCESS  uid://A001/X147/X170  1730-130_b_03_TE  2013.1.00428.S     Array008         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa18feb/X161b                BL   783130  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939224813552000000 AND START_VALID_TIME < 4939250013552000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa18feb/X161b'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939228337143252992.000000 AND START_VALID_TIME <4939249937143252992.000000
# Executing QUERY for QA0, please wait...
# ...
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939189090992000000 AND START_VALID_TIME < 4939214290992000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939191613143248896.000000 AND START_VALID_TIME <4939213213143248896.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939191613143248896.000000 AND START_VALID_TIME <4939213213143248896.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X4b05'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS                 SE_SB_ID      SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa16f89/X44e3  uid://A002/Xa16f89/X44e3 2015-05-24 17:54:12.149000        20   SUCCESS  uid://A002/X5d7935/X23e  DQ_Tau_a_06_12  2012.1.00496.S     Array002         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa16f89/X44e3                BL   782640  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939181728272000000 AND START_VALID_TIME < 4939206928272000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939185252143249408.000000 AND START_VALID_TIME <4939206852143249408.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939185252143249408.000000 AND START_VALID_TIME <4939206852143249408.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X44e3'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID        SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY  \
# SE_EB_UID
# uid://A002/Xa16f89/X3d53  uid://A002/Xa16f89/X3d53 2015-05-24 15:51:31.123001        72   SUCCESS  uid://A001/X13a/X145  L1527_IR_a_06_TC  2013.1.01086.S     Array002         12 [m]
#
#                          SE_CORRELATORTYPE  SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa16f89/X3d53                BL   782640  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939175341968000000 AND START_VALID_TIME < 4939200541968000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_ID, POSITION_VAL, NAME, STATION_ID FROM SCHEDULING_AOS.ASDM_ANTENNA WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FLAG_ID, NUM_ANTENNA, REASON,SPECTRAL_WINDOW_ID_VAL, ANTENNA_ID_VAL, START_TIME, END_TIME FROM SCHEDULING_AOS.ASDM_FLAG WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, NUM_SUBSCAN, NUM_FIELD, START_TIME,END_TIME, SCAN_INTENT_VAL, FIELD_NAME_VAL FROM SCHEDULING_AOS.ASDM_SCAN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT STATION_ID, ARCHIVE_UID, POSITION_VAL, NAME FROM SCHEDULING_AOS.ASDM_STATION WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, SCAN_NUMBER, SUBSCAN_NUMBER, START_TIME, END_TIME,FIELD_NAME, SUBSCAN_INTENT_ENUMV FROM SCHEDULING_AOS.ASDM_SUBSCAN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV, CAL_DATA_ID,START_VALID_TIME, OFFSET_VAL, OFFSET_ERROR_VAL, FREQUENCY_RANGE_VAL, AMBIENT_TEMPERATURE, POINTING_DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALFOCUS WHERE START_VALID_TIME > 4939177891143248896.000000 AND START_VALID_TIME <4939199491143248896.000000
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, ATM_PHASE_CORRECTION_ENUMV,BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV, CAL_DATA_ID,REF_ANTENNA_NAME,DELAY_OFFSET_VAL, POLARIZATION_TYPES_VAL,START_VALID_TIME, NUM_RECEPTOR, NUM_SIDEBAND, DELAY_ERROR_VAL FROM SCHEDULING_AOS.ASDM_CALDELAY WHERE START_VALID_TIME > 4939177891143248896.000000 AND START_VALID_TIME <4939199491143248896.000000
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, FIELD_ID, FIELD_NAME, SOURCE_ID, REFERENCE_DIR_VAL FROM SCHEDULING_AOS.ASDM_FIELD WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, TIME, CONFIG_DESCRIPTION_ID, NUM_ANTENNA, SUBSCAN_NUMBER, SCAN_NUMBER, FIELD_ID, TIME_SAMPLING_ENUMV FROM SCHEDULING_AOS.ASDM_MAIN WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, CAL_DATA_ID, WATER, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALWVR WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY for QA0, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, SCAN_SET_VAL, CAL_TYPE_ENUMV,START_TIME_OBSERVED FROM SCHEDULING_AOS.ASDM_CALDATA WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3d53'
# Executing QUERY, please wait...
#                                          SE_EB_UID                 START_TIME  NUM_SCAN SE_STATUS              SE_SB_ID    SE_SB_CODE SE_PROJECT_CODE SE_ARRAYNAME SE_ARRAYFAMILY SE_CORRELATORTYPE  \
# SE_EB_UID
# uid://A002/Xa16f89/X3890  uid://A002/Xa16f89/X3890 2015-05-24 14:38:12.069000        26   SUCCESS  uid://A001/X145/X36e  A383_a_06_TE  2013.1.01241.S     Array002         12 [m]                BL
#
#                           SE_ID_y                                         SE_SUBJECT
# SE_EB_UID
# uid://A002/Xa16f89/X3890   782640  StandardInterferometry.py NumPhaseCal=1 NumAmp...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3890'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, CAL_DATA_ID, ANTENNA_NAME,RECEIVER_BAND_ENUMV,COLL_OFFSET_ABSOLUTE_VAL, COLL_OFFSET_RELATIVE_VAL, COLL_ERROR_VAL,POLARIZATION_TYPES_VAL, BEAM_WIDTH_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME, DIRECTION_VAL FROM SCHEDULING_AOS.ASDM_CALPOINTING WHERE START_VALID_TIME > 4939170621120000000 AND START_VALID_TIME < 4939195821120000000
# Executing QUERY for QA1, please wait...
# SELECT ARCHIVE_UID, BASEBAND_NAME_ENUMV, RECEIVER_BAND_ENUMV,ATM_PHASE_CORRECTION_ENUMV, CAL_DATA_ID,DIRECTION_VAL, FREQUENCY_RANGE_VAL,ANTENNA_NAMES_VAL,BASELINE_LENGTHS_VAL, AMPLI_VAL,PHASE_R_M_S_VAL,POLARIZATION_TYPES_VAL, DECORRELATION_FACTOR_VAL,NUM_BASELINE, NUM_RECEPTOR,PHASE_VAL, START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALPHASE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3890'
# Executing QUERY, please wait...
# SELECT ARCHIVE_UID, ANTENNA_NAME, RECEIVER_BAND_ENUMV,baseband_name_enumv, CAL_DATA_ID,T_REC_VAL, T_SYS_VAL,SYSCAL_TYPE_ENUMV, POLARIZATION_TYPES_VAL,SB_GAIN_VAL, FREQUENCY_RANGE_VAL,START_VALID_TIME FROM SCHEDULING_AOS.ASDM_CALATMOSPHERE WHERE ARCHIVE_UID = 'uid://A002/Xa16f89/X3890'

# %%
uid = 'uid://A002/Xa18feb/X22b0'
print slt_eb.query('SE_EB_UID == @uid')
timeu = slt_eb.ix[uid, 'START_TIME']
tmjd = timeu.strftime('%Y-%m-%dT%H:%M:%S.%s')
point_eb = cal.query_point(c, uid, q1=True)
dfph = cal.query_phase(c, uid)
dfatm = cal.query_atm(c, uid)
dfant = cal.query_antennas(c, uid)
dfflag = cal.query_flags(c, uid)
dfflag.delta = dfflag.apply(lambda x: x['delta'].total_seconds(), axis=1)
dfscan = cal.query_scans(c, uid)
dfsta = cal.query_station(c, uid)
dfsubs = cal.query_subscans(c, uid)
dffoc = cal.query_focus(c, tmjd)
dfdel = cal.query_delay(c, tmjd)
dfield = cal.query_field(c, uid)
dfmain = cal.query_main(c, uid)
dfwvr = cal.query_wvr(c, uid)
dfcal = cal.query_caldata(c, uid)
ssys = ['Mars', 'Venus', 'Jupiter', 'Uranus', 'Neptune', 'Titan', 'Ceres', 'Ganymede', 'Callisto', 'Pallas']
calamp = dfscan.query("SCAN_INTENT in ['CALIBRATE_AMPLITUDE', 'CALIBRATE_AMPLI'] and FIELD_NAME not in @ssys").FIELD_NAME.unique()

if len(calamp) > 0:
    cou = 0
    for ca in calamp:
        sql_names = 'SELECT * FROM sourcecatalogue.names WHERE SOURCE_NAME = \'%s\'' % ca
        c.execute(sql_names)
        names = pd.DataFrame(
            c.fetchall(),
            columns=[rec[0] for rec in c.description])

        name_id = names.NAME_ID.values[0]

        sql_sourcename = 'SELECT * FROM sourcecatalogue.source_name WHERE NAME_ID = \'%s\'' % name_id
        c.execute(sql_sourcename)
        source_name = pd.DataFrame(
            c.fetchall(), columns=[rec[0] for rec in c.description])
        source_id = source_name.SOURCE_ID.values[0]
        c.execute('SELECT * FROM SOURCECATALOGUE.MEASUREMENTS WHERE SOURCE_ID = \'%s\'' % source_id)
        measurements_df = pd.DataFrame(
            c.fetchall(),
            columns=[rec[0] for rec in c.description])
        if cou == 0:
            cal_amp = measurements_df.query('FREQUENCY < 1.40e11').sort('DATE_OBSERVED', ascending=False).head(1)
            cal_amp = cal_amp.append(measurements_df.query('FREQUENCY > 2.00e11').sort('DATE_OBSERVED', ascending=False).head(1))
            cou = 1
        else:
            cal_amp = cal_amp.append(measurements_df.query('FREQUENCY > 2.00e11').sort('DATE_OBSERVED', ascending=False).head(1))
            cal_amp = cal_amp.append(measurements_df.query('FREQUENCY < 1.40e11').sort('DATE_OBSERVED', ascending=False).head(1))
else:
    cal_amp = pd.DataFrame([(0,0)], columns=['MEASUREMENT_ID', 'CAT_ID'])

# %%
dire = '_'.join(uid.split('/')[-2:])
try:
    os.mkdir('data/' + dire)
except OSError:
    shutil.rmtree('data/' + dire)
    os.mkdir('data/' + dire)

# %%
point_eb[0].to_csv('data/' + dire + '/point_qa0.csv', index=False)
antenas = dfant.ANTENNA.unique()
point_eb[1].query('ANTENNA in @antenas').to_csv('data/' + dire + '/point_qa1.csv', index=False)
dfant.to_csv('data/' + dire + '/antennas.csv', index=False)
dfph.to_csv('data/' + dire + '/phase.csv', index=False)
dfwvr.to_csv('data/' + dire + '/wvr.csv', index=False)
dfscan.to_csv('data/' + dire + '/scan.csv', index=False)
dfatm.to_csv('data/' + dire + '/atmosphere.csv', index=False)
dfdel.query('ANTENNA in @antenas').to_csv('data/' + dire + '/delay.csv', index=False)
dfmain.to_csv('data/' + dire + '/main.csv', index=False)
dfield.to_csv('data/' + dire + '/field.csv', index=False)
dffoc.query('ANTENNA in @antenas').to_csv('data/' + dire + '/focus.csv', index=False)
dfsubs.to_csv('data/' + dire + '/subscans.csv', index=False)
dfflag.to_csv('data/' + dire + '/flags.csv', index=False)
dfcal.to_csv('data/' + dire + '/caldata.csv', index=False)
slt_eb.query('SE_EB_UID == @uid').to_csv('data/' + dire + '/slt.csv', index=False)
sbuid = slt_eb.query('SE_EB_UID == @uid').SE_SB_ID.values[0]
datas.summary_sb.query("SB_UID == @sbuid").to_csv('data/' + dire + '/sbsum.csv', index=False)
scpar = datas.scienceparam.query('SB_UID == @sbuid').paramRef.unique()
tar = datas.target.query('SB_UID == @sbuid and paramRef in @scpar').fieldRef.unique()
datas.fieldsource.query('SB_UID == @sbuid and @tar in fieldRef').to_csv('data/' + dire + '/fieldsource.csv', index=False)
datas.scienceparam.query('SB_UID == @sbuid').to_csv('data/' + dire + '/scienceparam.csv', index=False)
cal_amp.to_csv('data/' + dire + '/cal_amp.csv', index=False)

# %%
dfflag.groupby(['ANTENNA_ID', 'REASON']).agg({'FLAG_ID': pd.np.count_nonzero, 'delta' : np.sum}).head(15)
# Out:
#                                                                      FLAG_ID      delta
# ANTENNA_ID REASON
# Antenna_0  Calibration device (ACD) is not in the correct position.       94  38.399895
#            FrontEnd LO Amps not optimized                                  3   0.576546
#            Mount is off source                                            35  60.671997
#            Power levels are being optimized.                               4   3.649669
#            The WCA is not locked.                                          4   5.535401
# Antenna_1  Calibration device (ACD) is not in the correct position.       94  38.532465
#            FrontEnd LO Amps not optimized                                  3   0.548809
#            Mount is off source                                            37  65.711993
#            Power levels are being optimized.                               4   3.646906
#            The WCA is not locked.                                          3   4.173152
# Antenna_10 Calibration device (ACD) is not in the correct position.       94  37.943274
#            FrontEnd LO Amps not optimized                                  3   0.439703
#            Mount is off source                                            35  59.375998
#            Power levels are being optimized.                               4   3.640155
#            The WCA is not locked.                                          4   7.658515

# %%
cal_amp
# Out:
#    MEASUREMENT_ID  CAT_ID
# 0               0       0

# %%
uid
# Out:
# 'uid://A002/Xa18feb/X22b0'

# %%
# point_trend = point_eb[1].copy()
# point_trend['TIME'] = point_trend.apply(lambda x: x['TIME'].strftime('%Y-%m-%d %H:%M:%S'), axis=1)
# point_trend.to_csv('/home/itoledo/Downloads/point.csv', date_format="%Y-%m-%d %H:%M:%S", enconding='utf-8', index=False)
